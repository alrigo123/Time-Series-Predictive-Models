# %% [markdown]
# # **ANN LSTM univariate model for the prediction of meteorological time series data.**

# %% [markdown]
# # **LSTM for forecasting**
# *Code used and adapted from reference:*  **https://colab.research.google.com/drive/1HxPsJvEAH8L7XTmLnfdJ3UQx7j0o1yX5?usp=sharing**

# %% [markdown]
# # LIBRARIES

# %%
# IMPORT LIBRARIES
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, InputLayer, Dropout, Bidirectional
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, Huber
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # DATA WORK

# %% [markdown]
# ---
# Change the data file path with yours

# %%
# LOAD DATA

location = '/content/drive/MyDrive/Colab Notebooks/MACHINE LEARNING TESIS/TIME-SERIES-Diario-13-23.csv'  ## DAILY DATA
# location = '/content/drive/MyDrive/Colab Notebooks/MACHINE LEARNING TESIS/TIME-SERIES-Mensual-86-23.csv' ## MONTHLY DATA

data = pd.read_csv(location, parse_dates=['Fecha'], infer_datetime_format=True) # PARSE COLUMN "FECHA" TO DATE TYPE
data = data.set_index(['Fecha']) # SET INDEX
data.head()
# Out:
# <ipython-input-37-1240d6fbcb2e>:6: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data = pd.read_csv(location, parse_dates=['Fecha'], infer_datetime_format=True) # PARSE COLUMN "FECHA" TO DATE TYPE
#              Año  Mes  Dia  Tｰ Media  TｰMaxima  TｰMinima  Lluvia  %Humedad
# Fecha
# 2013-01-01  2013  Ene    1    12.038    18.022     7.344   0.956    73.676
# 2013-01-02  2013  Ene    2    12.224    18.000     8.078   3.600    74.553
# 2013-01-03  2013  Ene    3    11.902    17.822     7.667   9.933    76.719
# 2013-01-04  2013  Ene    4    10.906    16.778     7.122   8.800    79.117
# 2013-01-05  2013  Ene    5    11.146    16.267     7.211   4.956    79.746

# %%
# CHANGE HEADER NAMES
data = data.rename(columns={"Tｰ Media": "Temp_media", "TｰMaxima": "Temp_max", "TｰMinima": "Temp_min", "Lluvia": "Precipitacion", "%Humedad": "Humedad"})

# DROP COLUMNS THAT ARE NOT GOING TO BE USED
data = data.drop(["Año", "Dia", "Mes", "Temp_media", "Humedad", "Precipitacion", "Temp_min"], axis=1) # DAILY MAXIMUM TEMPERATURE DATA FRAME
# data = data.drop(["Año", "Mes", "Temp_media", "Humedad", "Temp_min", "Precipitacion"], axis=1)# # MONTHLY MAXIMUM TEMPERATURE DATA FRAME

# %%
## SET NAME OF THE TARGET VARIABLE
temp = data["Temp_max"]

temp.head()
# Out:
# Fecha
# 2013-01-01    18.022
# 2013-01-02    18.000
# 2013-01-03    17.822
# 2013-01-04    16.778
# 2013-01-05    16.267
# Name: Temp_max, dtype: float64

# %% [markdown]
# ## DATA TRANSFORMATION

# %%
temp.dropna(inplace=True)

# %%
temp_samples = len(temp)

# %%
# Normalización
scaler = MinMaxScaler()
temp_scaled = scaler.fit_transform(temp.values.reshape(-1, 1))

# %% [markdown]
# ### SLIDING WINDOW

# %%
# CREATE SLIDING WINDOWS
def df_to_X_y(df, window_size=3):
    df_as_np = df
    X = []
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i + window_size]]
        X.append(row)
        label = df_as_np[i + window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %% [markdown]
# *window_size* : Este parámetro define el número de pasos de tiempo anteriores que el modelo usará para predecir el siguiente valor. Es crucial porque determina cuánta información histórica el modelo considera para hacer una predicción.

# %%
WINDOW_SIZE = 3  ## SET NUMBER OF WINDOWS SLIDES
X1, y1 = df_to_X_y(temp_scaled, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((3880, 3, 1, 1), (3880, 1))

# %% [markdown]
# # DATA SPLIT

# %%
# CALCULATE SIZE
test_size = int(temp_samples * 0.2)  # 20% TEST
train_val_size = temp_samples - test_size  # 80% TRAIN + VALIDATION

# SPLIT IN TRAIN + VALIDATION AND TEST
X_train_val, y_train_val = X1[:train_val_size], y1[:train_val_size]
X_test1, y_test1 = X1[train_val_size:], y1[train_val_size:]

# %%
# Ahora dividir el conjunto de entrenamiento + validación
# Supongamos que el 10% de los datos totales son para validación (o el 12.5% del conjunto de entrenamiento + validación)
validation_fraction = 0.125
val_size = int(train_val_size * validation_fraction)

# División en entrenamiento y validación
X_train1, y_train1 = X_train_val[:-val_size], y_train_val[:-val_size]
X_val1, y_val1 = X_train_val[-val_size:], y_train_val[-val_size:]

# Verificar formas de los conjuntos
print(f"Training set shape: {X_train1.shape, y_train1.shape}")
print(f"Validation set shape: {X_val1.shape, y_val1.shape}")
print(f"Test set shape: {X_test1.shape, y_test1.shape}")
# Out:
# Training set shape: ((2719, 3, 1, 1), (2719, 1))
# Validation set shape: ((388, 3, 1, 1), (388, 1))
# Test set shape: ((773, 3, 1, 1), (773, 1))

# %% [markdown]
# # MODEL BUILD

# %%
## CHANGE PARAMETERS (ADD LAYERS, NEURONS OR TYPE)
model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model1/a.keras', save_best_only=True) ## saev the best model of the validation
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError(), MeanAbsoluteError(), MeanAbsolutePercentageError()])  # learning_rate , the faster the model create the clusters

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=50, callbacks=[cp1])
# Out:
# Epoch 1/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3520 - mean_absolute_error: 0.5828 - mean_absolute_percentage_error: 92.6930 - root_mean_squared_error: 0.5931 - val_loss: 0.2695 - val_mean_absolute_error: 0.5086 - val_mean_absolute_percentage_error: 78.4080 - val_root_mean_squared_error: 0.5191
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2284 - mean_absolute_error: 0.4652 - mean_absolute_percentage_error: 72.8776 - root_mean_squared_error: 0.4774 - val_loss: 0.1474 - val_mean_absolute_error: 0.3713 - val_mean_absolute_percentage_error: 56.6756 - val_root_mean_squared_error: 0.3840
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1128 - mean_absolute_error: 0.3195 - mean_absolute_percentage_error: 49.8569 - root_mean_squared_error: 0.3353 - val_loss: 0.0524 - val_mean_absolute_error: 0.2111 - val_mean_absolute_percentage_error: 31.6439 - val_root_mean_squared_error: 0.2289
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0373 - mean_absolute_error: 0.1708 - mean_absolute_percentage_error: 26.3528 - root_mean_squared_error: 0.1922 - val_loss: 0.0136 - val_mean_absolute_error: 0.0951 - val_mean_absolute_percentage_error: 14.6424 - val_root_mean_squared_error: 0.1165
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0872 - mean_absolute_percentage_error: 14.8764 - root_mean_squared_error: 0.1084 - val_loss: 0.0092 - val_mean_absolute_error: 0.0753 - val_mean_absolute_percentage_error: 12.4609 - val_root_mean_squared_error: 0.0957
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0764 - mean_absolute_percentage_error: 13.5659 - root_mean_squared_error: 0.0981 - val_loss: 0.0090 - val_mean_absolute_error: 0.0740 - val_mean_absolute_percentage_error: 12.3973 - val_root_mean_squared_error: 0.0948
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0760 - mean_absolute_percentage_error: 13.9078 - root_mean_squared_error: 0.0987 - val_loss: 0.0090 - val_mean_absolute_error: 0.0739 - val_mean_absolute_percentage_error: 12.3901 - val_root_mean_squared_error: 0.0947
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - mean_absolute_error: 0.0777 - mean_absolute_percentage_error: 14.0598 - root_mean_squared_error: 0.1004 - val_loss: 0.0089 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 12.3907 - val_root_mean_squared_error: 0.0945
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0766 - mean_absolute_percentage_error: 14.0639 - root_mean_squared_error: 0.1000 - val_loss: 0.0090 - val_mean_absolute_error: 0.0740 - val_mean_absolute_percentage_error: 12.3822 - val_root_mean_squared_error: 0.0947
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - mean_absolute_error: 0.0778 - mean_absolute_percentage_error: 14.0483 - root_mean_squared_error: 0.1002 - val_loss: 0.0089 - val_mean_absolute_error: 0.0738 - val_mean_absolute_percentage_error: 12.3715 - val_root_mean_squared_error: 0.0946
# Epoch 11/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 13.4353 - root_mean_squared_error: 0.0967 - val_loss: 0.0090 - val_mean_absolute_error: 0.0740 - val_mean_absolute_percentage_error: 12.3696 - val_root_mean_squared_error: 0.0947
# Epoch 12/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0101 - mean_absolute_error: 0.0784 - mean_absolute_percentage_error: 14.1291 - root_mean_squared_error: 0.1006 - val_loss: 0.0090 - val_mean_absolute_error: 0.0739 - val_mean_absolute_percentage_error: 12.3614 - val_root_mean_squared_error: 0.0946
# Epoch 13/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0773 - mean_absolute_percentage_error: 14.1220 - root_mean_squared_error: 0.1001 - val_loss: 0.0089 - val_mean_absolute_error: 0.0736 - val_mean_absolute_percentage_error: 12.3486 - val_root_mean_squared_error: 0.0944
# Epoch 14/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0756 - mean_absolute_percentage_error: 13.5122 - root_mean_squared_error: 0.0986 - val_loss: 0.0089 - val_mean_absolute_error: 0.0736 - val_mean_absolute_percentage_error: 12.3417 - val_root_mean_squared_error: 0.0944
# Epoch 15/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0102 - mean_absolute_error: 0.0779 - mean_absolute_percentage_error: 14.1705 - root_mean_squared_error: 0.1011 - val_loss: 0.0090 - val_mean_absolute_error: 0.0742 - val_mean_absolute_percentage_error: 12.3503 - val_root_mean_squared_error: 0.0948
# Epoch 16/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0735 - mean_absolute_percentage_error: 12.9041 - root_mean_squared_error: 0.0948 - val_loss: 0.0090 - val_mean_absolute_error: 0.0742 - val_mean_absolute_percentage_error: 12.3461 - val_root_mean_squared_error: 0.0948
# Epoch 17/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0772 - mean_absolute_percentage_error: 13.6614 - root_mean_squared_error: 0.0996 - val_loss: 0.0089 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 12.3159 - val_root_mean_squared_error: 0.0943
# Epoch 18/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0095 - mean_absolute_error: 0.0750 - mean_absolute_percentage_error: 13.6209 - root_mean_squared_error: 0.0974 - val_loss: 0.0088 - val_mean_absolute_error: 0.0731 - val_mean_absolute_percentage_error: 12.3064 - val_root_mean_squared_error: 0.0941
# Epoch 19/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 13.4960 - root_mean_squared_error: 0.0976 - val_loss: 0.0089 - val_mean_absolute_error: 0.0733 - val_mean_absolute_percentage_error: 12.2959 - val_root_mean_squared_error: 0.0941
# Epoch 20/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0097 - mean_absolute_error: 0.0765 - mean_absolute_percentage_error: 13.5400 - root_mean_squared_error: 0.0986 - val_loss: 0.0088 - val_mean_absolute_error: 0.0728 - val_mean_absolute_percentage_error: 12.2910 - val_root_mean_squared_error: 0.0939
# Epoch 21/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - mean_absolute_error: 0.0771 - mean_absolute_percentage_error: 13.7900 - root_mean_squared_error: 0.0988 - val_loss: 0.0088 - val_mean_absolute_error: 0.0732 - val_mean_absolute_percentage_error: 12.2773 - val_root_mean_squared_error: 0.0941
# Epoch 22/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0099 - mean_absolute_error: 0.0775 - mean_absolute_percentage_error: 13.8385 - root_mean_squared_error: 0.0994 - val_loss: 0.0089 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 12.2763 - val_root_mean_squared_error: 0.0942
# Epoch 23/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0777 - mean_absolute_percentage_error: 14.0396 - root_mean_squared_error: 0.1010 - val_loss: 0.0088 - val_mean_absolute_error: 0.0726 - val_mean_absolute_percentage_error: 12.2585 - val_root_mean_squared_error: 0.0937
# Epoch 24/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0774 - mean_absolute_percentage_error: 14.1964 - root_mean_squared_error: 0.1010 - val_loss: 0.0088 - val_mean_absolute_error: 0.0733 - val_mean_absolute_percentage_error: 12.2543 - val_root_mean_squared_error: 0.0940
# Epoch 25/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0739 - mean_absolute_percentage_error: 13.1897 - root_mean_squared_error: 0.0963 - val_loss: 0.0089 - val_mean_absolute_error: 0.0740 - val_mean_absolute_percentage_error: 12.2751 - val_root_mean_squared_error: 0.0945
# Epoch 26/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0755 - mean_absolute_percentage_error: 13.5826 - root_mean_squared_error: 0.0975 - val_loss: 0.0088 - val_mean_absolute_error: 0.0729 - val_mean_absolute_percentage_error: 12.2256 - val_root_mean_squared_error: 0.0938
# Epoch 27/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0762 - mean_absolute_percentage_error: 13.7087 - root_mean_squared_error: 0.0979 - val_loss: 0.0088 - val_mean_absolute_error: 0.0727 - val_mean_absolute_percentage_error: 12.2105 - val_root_mean_squared_error: 0.0936
# Epoch 28/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 13.9899 - root_mean_squared_error: 0.0989 - val_loss: 0.0087 - val_mean_absolute_error: 0.0724 - val_mean_absolute_percentage_error: 12.2002 - val_root_mean_squared_error: 0.0934
# Epoch 29/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0761 - mean_absolute_percentage_error: 13.7261 - root_mean_squared_error: 0.0985 - val_loss: 0.0090 - val_mean_absolute_error: 0.0742 - val_mean_absolute_percentage_error: 12.2621 - val_root_mean_squared_error: 0.0946
# Epoch 30/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0766 - mean_absolute_percentage_error: 13.8503 - root_mean_squared_error: 0.0986 - val_loss: 0.0087 - val_mean_absolute_error: 0.0723 - val_mean_absolute_percentage_error: 12.1748 - val_root_mean_squared_error: 0.0933
# Epoch 31/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0099 - mean_absolute_error: 0.0766 - mean_absolute_percentage_error: 14.0257 - root_mean_squared_error: 0.0996 - val_loss: 0.0087 - val_mean_absolute_error: 0.0726 - val_mean_absolute_percentage_error: 12.1685 - val_root_mean_squared_error: 0.0935
# Epoch 32/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0741 - mean_absolute_percentage_error: 13.4600 - root_mean_squared_error: 0.0972 - val_loss: 0.0087 - val_mean_absolute_error: 0.0723 - val_mean_absolute_percentage_error: 12.1515 - val_root_mean_squared_error: 0.0933
# Epoch 33/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0091 - mean_absolute_error: 0.0736 - mean_absolute_percentage_error: 13.1779 - root_mean_squared_error: 0.0952 - val_loss: 0.0087 - val_mean_absolute_error: 0.0727 - val_mean_absolute_percentage_error: 12.1557 - val_root_mean_squared_error: 0.0934
# Epoch 34/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0766 - mean_absolute_percentage_error: 14.1945 - root_mean_squared_error: 0.0992 - val_loss: 0.0086 - val_mean_absolute_error: 0.0718 - val_mean_absolute_percentage_error: 12.1279 - val_root_mean_squared_error: 0.0930
# Epoch 35/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0737 - mean_absolute_percentage_error: 13.0976 - root_mean_squared_error: 0.0946 - val_loss: 0.0087 - val_mean_absolute_error: 0.0722 - val_mean_absolute_percentage_error: 12.1187 - val_root_mean_squared_error: 0.0931
# Epoch 36/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0755 - mean_absolute_percentage_error: 13.6148 - root_mean_squared_error: 0.0978 - val_loss: 0.0087 - val_mean_absolute_error: 0.0722 - val_mean_absolute_percentage_error: 12.1088 - val_root_mean_squared_error: 0.0931
# Epoch 37/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0747 - mean_absolute_percentage_error: 13.2977 - root_mean_squared_error: 0.0968 - val_loss: 0.0087 - val_mean_absolute_error: 0.0725 - val_mean_absolute_percentage_error: 12.1135 - val_root_mean_squared_error: 0.0932
# Epoch 38/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0091 - mean_absolute_error: 0.0745 - mean_absolute_percentage_error: 13.1643 - root_mean_squared_error: 0.0952 - val_loss: 0.0086 - val_mean_absolute_error: 0.0721 - val_mean_absolute_percentage_error: 12.0898 - val_root_mean_squared_error: 0.0930
# Epoch 39/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0096 - mean_absolute_error: 0.0761 - mean_absolute_percentage_error: 13.7095 - root_mean_squared_error: 0.0977 - val_loss: 0.0088 - val_mean_absolute_error: 0.0735 - val_mean_absolute_percentage_error: 12.1570 - val_root_mean_squared_error: 0.0939
# Epoch 40/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0093 - mean_absolute_error: 0.0748 - mean_absolute_percentage_error: 13.4134 - root_mean_squared_error: 0.0963 - val_loss: 0.0087 - val_mean_absolute_error: 0.0723 - val_mean_absolute_percentage_error: 12.0779 - val_root_mean_squared_error: 0.0930
# Epoch 41/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0721 - mean_absolute_percentage_error: 12.9199 - root_mean_squared_error: 0.0947 - val_loss: 0.0087 - val_mean_absolute_error: 0.0725 - val_mean_absolute_percentage_error: 12.0791 - val_root_mean_squared_error: 0.0931
# Epoch 42/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0090 - mean_absolute_error: 0.0736 - mean_absolute_percentage_error: 13.2001 - root_mean_squared_error: 0.0949 - val_loss: 0.0085 - val_mean_absolute_error: 0.0712 - val_mean_absolute_percentage_error: 12.0284 - val_root_mean_squared_error: 0.0924
# Epoch 43/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0091 - mean_absolute_error: 0.0730 - mean_absolute_percentage_error: 13.1315 - root_mean_squared_error: 0.0952 - val_loss: 0.0087 - val_mean_absolute_error: 0.0726 - val_mean_absolute_percentage_error: 12.0692 - val_root_mean_squared_error: 0.0931
# Epoch 44/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0096 - mean_absolute_error: 0.0749 - mean_absolute_percentage_error: 13.6027 - root_mean_squared_error: 0.0980 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719 - val_mean_absolute_percentage_error: 12.0252 - val_root_mean_squared_error: 0.0926
# Epoch 45/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0764 - mean_absolute_percentage_error: 14.0284 - root_mean_squared_error: 0.0991 - val_loss: 0.0086 - val_mean_absolute_error: 0.0718 - val_mean_absolute_percentage_error: 12.0119 - val_root_mean_squared_error: 0.0926
# Epoch 46/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0091 - mean_absolute_error: 0.0741 - mean_absolute_percentage_error: 13.3733 - root_mean_squared_error: 0.0955 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719 - val_mean_absolute_percentage_error: 12.0075 - val_root_mean_squared_error: 0.0926
# Epoch 47/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0748 - mean_absolute_percentage_error: 13.6796 - root_mean_squared_error: 0.0974 - val_loss: 0.0086 - val_mean_absolute_error: 0.0724 - val_mean_absolute_percentage_error: 12.0317 - val_root_mean_squared_error: 0.0929
# Epoch 48/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0757 - mean_absolute_percentage_error: 14.0044 - root_mean_squared_error: 0.0985 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719 - val_mean_absolute_percentage_error: 11.9935 - val_root_mean_squared_error: 0.0925
# Epoch 49/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0761 - mean_absolute_percentage_error: 13.8038 - root_mean_squared_error: 0.0988 - val_loss: 0.0084 - val_mean_absolute_error: 0.0709 - val_mean_absolute_percentage_error: 11.9409 - val_root_mean_squared_error: 0.0919
# Epoch 50/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0722 - mean_absolute_percentage_error: 12.6623 - root_mean_squared_error: 0.0924 - val_loss: 0.0085 - val_mean_absolute_error: 0.0713 - val_mean_absolute_percentage_error: 11.9427 - val_root_mean_squared_error: 0.0921

# %%
# from tensorflow.keras.models import load_model
# model1 = load_model('model1/')  ###

# %% [markdown]
# ## MODEL PREDICTION

# %%
train_predictions = model1.predict(X_train1).flatten()
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Desescalar las predicciones
train_predictions = scaler.inverse_transform(train_predictions.reshape(-1, 1)).flatten()
y_train_actual = scaler.inverse_transform(y_train1.reshape(-1, 1)).flatten()

# %% [markdown]
# ### TRAIN RESULTS

# %%
# Resultados de entrenamiento
train_results = pd.DataFrame(data={'Train Predictions': train_predictions, 'Actuals': y_train_actual})
train_results
# Out:
#       Train Predictions  Actuals
# 0             17.872887   16.778
# 1             17.596994   16.267
# 2             17.252161   17.522
# 3             17.253910   17.922
# 4             17.490211   17.967
# ...                 ...      ...
# 2714          18.013399   18.000
# 2715          18.335239   19.100
# 2716          18.377785   18.900
# 2717          18.324675   19.400
# 2718          18.600607   15.800
#
# [2719 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Actuals'][500:1000])
plt.plot(train_results['Train Predictions'][500:1000])

# %%
# Graficar resultados de entrenamiento
plt.figure(figsize=(14, 7))
plt.plot(train_results['Actuals'], label='Actuals')
plt.plot(train_results['Train Predictions'], label='Train Predictions')
plt.title('Training Results')
plt.legend()
plt.show()

# %% [markdown]
# ### VALIDATION RESULTS

# %%
# Predicciones en conjunto de validación
val_predictions = model1.predict(X_val1).flatten()
val_predictions = scaler.inverse_transform(val_predictions.reshape(-1, 1)).flatten()
y_val_actual = scaler.inverse_transform(y_val1.reshape(-1, 1)).flatten()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Resultados de validación
val_results = pd.DataFrame(data={'Val Predictions': val_predictions, 'Actuals': y_val_actual})
val_results
# Out:
#      Val Predictions  Actuals
# 0          17.831364     14.6
# 1          16.969353     18.2
# 2          16.916748     19.8
# 3          17.743841     20.9
# 4          18.954967     19.3
# ..               ...      ...
# 383        17.887753     17.6
# 384        17.817219     18.6
# 385        17.952734     18.8
# 386        18.134447     17.9
# 387        18.146326     18.8
#
# [388 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][:100])
plt.plot(val_results['Val Predictions'][:100])

# %%
# Graficar resultados de validación
plt.figure(figsize=(14, 7))
plt.plot(val_results['Actuals'], label='Actuals')
plt.plot(val_results['Val Predictions'], label='Val Predictions')
plt.title('Validation Results')
plt.legend()
plt.show()

# %% [markdown]
# ### TEST RESULTS

# %%
# Predicciones en conjunto de prueba
test_predictions = model1.predict(X_test1).flatten()
test_predictions = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()
y_test_actual = scaler.inverse_transform(y_test1.reshape(-1, 1)).flatten()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Resultados de prueba
test_results = pd.DataFrame(data={'Test Predictions': test_predictions, 'Actuals': y_test_actual})
test_results
# Out:
#      Test Predictions  Actuals
# 0           18.217703    17.70
# 1           17.974586    19.20
# 2           18.271269    19.70
# 3           18.473091    15.20
# 4           17.803453    17.70
# ..                ...      ...
# 768         17.622841    18.84
# 769         17.886438    19.06
# 770         18.199835    18.62
# 771         18.404470    17.83
# 772         18.178816    18.38
#
# [773 rows x 2 columns]

# %%
plt.plot(test_results['Actuals'][:100])
plt.plot(test_results['Test Predictions'][:100])

# %%
# # Graficar resultados de prueba
# plt.figure(figsize=(14, 7))
# plt.plot(test_results['Actuals'], label='Actuals')
# plt.plot(test_results['Test Predictions'], label='Test Predictions')
# plt.title('Test Results')
# plt.legend()
# plt.show()

# %% [markdown]
# ## EVALUATION

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
import pandas as pd

# Función para graficar predicciones y calcular métricas
def plot_predictions1(model, X, y, scaler, start=0, end=800):
    predictions = model.predict(X).flatten()
    # Inversa de la transformación para obtener los valores reales
    predictions = scaler.inverse_transform(predictions.reshape(-1, 1)).flatten()
    y_actual = scaler.inverse_transform(y.reshape(-1, 1)).flatten()

    # Crear DataFrame con los valores predichos y reales
    df = pd.DataFrame(data={'Predictions': predictions, 'Actuals': y_actual})

    # Graficar
    plt.figure(figsize=(14, 7))
    plt.plot(df['Actuals'][start:end], label='Actuals')
    plt.plot(df['Predictions'][start:end], label='Predictions')
    plt.title(f'Predictions vs Actuals (Samples {start} to {end})')
    plt.legend()
    plt.show()

    # Calcular métricas
    test_mse = mse(y_actual, predictions)
    test_rmse = test_mse ** 0.5  # Calcular RMSE a partir de MSE
    test_mae = mae(y_actual, predictions)

    print(f"\nTest MSE: {test_mse:.4f}")
    print(f"Test RMSE: {test_rmse:.4f}")
    print(f"Test MAE: {test_mae:.4f}\n")

    return df, test_mse, test_rmse, test_mae

# %%
# Uso de la función para graficar
_, test_mse, test_rmse, test_mae = plot_predictions1(model1, X_test1, y_test1, scaler)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test MSE: 3.1993
# Test RMSE: 1.7887
# Test MAE: 1.3807

# %% [markdown]
# # GRAPHICS

# %%
# Asumimos que los conjuntos de datos están alineados secuencialmente.
# Obtenemos los índices totales para concatenar los conjuntos.
train_len = len(train_results)
val_len = len(val_results)
test_len = len(test_results)

# Gráficamos todo junto pero respetando el orden secuencial de los datos.
plt.figure(figsize=(18, 9))

# Datos de entrenamiento
plt.plot(range(train_len), train_results['Actuals'], label='TRAIN', color='blue', alpha=0.9)
# plt.plot(range(train_len), train_results['Train Predictions'], label='Train Predictions', linestyle='--', color='cyan')

# Datos de validación
plt.plot(range(train_len, train_len + val_len), val_results['Actuals'], label='VALIDATION', color='green', alpha=0.9)
plt.plot(range(train_len, train_len + val_len), val_results['Val Predictions'], label='VALIDATION Prediction', linestyle='-', color='yellow')

# Datos de prueba
plt.plot(range(train_len + val_len, train_len + val_len + test_len), test_results['Actuals'], label='TEST', color='red', alpha=0.8)
plt.plot(range(train_len + val_len, train_len + val_len + test_len), test_results['Test Predictions'], label='TEST Prediction', linestyle='-', color='orange')

plt.title('Model Predictions vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Maximum Temperature')
plt.legend()
plt.show()

# %%
# Supongamos que ya tienes tus resultados de entrenamiento y prueba.
# Obtener las longitudes de cada conjunto.
train_len = len(train_results)
test_len = len(test_results)

# Crear un gráfico de tamaño adecuado.
plt.figure(figsize=(12, 6))

# Graficar los datos de entrenamiento.
plt.plot(range(train_len), train_results['Actuals'], label='Actuals (Train)', color='blue', alpha=0.7)

# Graficar los datos de prueba.
plt.plot(range(train_len, train_len + test_len), test_results['Actuals'], label='Actuals (Test)', color='red', alpha=0.7)

# Graficar las predicciones sobre el conjunto de prueba.
plt.plot(range(train_len, train_len + test_len), test_results['Test Predictions'], label='Predictions (Test)', linestyle='-', color='orange')

# Añadir título y etiquetas de los ejes.
plt.title('Model Predictions vs Actual Data (Test Set)')
plt.xlabel('Date')
plt.ylabel('Maximum Temperature')

# Añadir la leyenda.
plt.legend()

# Mostrar el gráfico.
plt.show()

# %%
import matplotlib.pyplot as plt

# Graficar resultados de entrenamiento, validación y prueba en un solo gráfico
plt.figure(figsize=(16, 8))

# Datos de entrenamiento
train_predictions = model1.predict(X_train1).flatten()
train_predictions = scaler.inverse_transform(train_predictions.reshape(-1, 1)).flatten()
y_train_actual = scaler.inverse_transform(y_train1.reshape(-1, 1)).flatten()
plt.plot(range(len(y_train_actual)), y_train_actual, label='Actuals (Train)', color='blue')
plt.plot(range(len(train_predictions)), train_predictions, label='Predictions (Train)', linestyle='--', color='cyan')

# Datos de validación
val_predictions = model1.predict(X_val1).flatten()
val_predictions = scaler.inverse_transform(val_predictions.reshape(-1, 1)).flatten()
y_val_actual = scaler.inverse_transform(y_val1.reshape(-1, 1)).flatten()
plt.plot(range(len(y_train_actual), len(y_train_actual) + len(y_val_actual)), y_val_actual, label='Actuals (Val)', color='green')
plt.plot(range(len(y_train_actual), len(y_train_actual) + len(val_predictions)), val_predictions, label='Predictions (Val)', linestyle='--', color='lightgreen')

# Datos de prueba
test_predictions = model1.predict(X_test1).flatten()
test_predictions = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()
y_test_actual = scaler.inverse_transform(y_test1.reshape(-1, 1)).flatten()
plt.plot(range(len(y_train_actual) + len(y_val_actual), len(y_train_actual) + len(y_val_actual) + len(y_test_actual)), y_test_actual, label='Actuals (Test)', color='red')
plt.plot(range(len(y_train_actual) + len(y_val_actual), len(y_train_actual) + len(y_val_actual) + len(test_predictions)), test_predictions, label='Predictions (Test)', linestyle='--', color='orange')

plt.title('Model Predictions vs Actual Data')
plt.xlabel('Date')
plt.ylabel('Maximum Temperature')
plt.legend()
plt.show()
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
